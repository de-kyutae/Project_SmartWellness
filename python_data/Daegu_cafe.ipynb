# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/상가(상권)정보_20200221/상가업소정보_201912_02.xlsx")
df
# Out:
#           상가업소번호        상호명        지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19917773       대구통닭  통통치킨상인2호점         Q       음식       Q05
# 1       19919475        빵마루        NaN         Q       음식       Q08
# 2       19925178       오구피자        NaN         Q       음식       Q07
# 3       19907335   명진가마솥오곡밥        NaN         Q       음식       Q01
# 4       19909700    이오쇠고기국밥        NaN         Q       음식       Q01
# ...          ...        ...        ...       ...      ...       ...
# 528306  16314214        A모텔        NaN         O       숙박       O02
# 528307  16292329       하얀기쁨        NaN         F    생활서비스       F02
# 528308  16292506        쭈네일        NaN         F    생활서비스       F01
# 528309  16394366     효소먹은돼지        NaN         Q       음식       Q01
# 528310  16335149  더칼라네일&속눈썹        NaN         F    생활서비스       F01
#
#          상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호     건물명  \
# ...

# %%
df = df.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528311 entries, 0 to 528310
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     528311 non-null  int64
#  1   상호명        528311 non-null  object
#  2   지점명        63168 non-null   object
#  3   상권업종대분류코드  528311 non-null  object
#  4   상권업종대분류명   528311 non-null  object
#  5   상권업종중분류코드  528311 non-null  object
#  6   상권업종중분류명   528311 non-null  object
#  7   상권업종소분류코드  528311 non-null  object
#  8   상권업종소분류명   528311 non-null  object
#  9   표준산업분류코드   496133 non-null  object
#  10  표준산업분류명    496133 non-null  object
#  11  시도코드       528311 non-null  int64
#  12  시도명        528311 non-null  object
#  13  시군구코드      528311 non-null  int64
#  14  시군구명       528311 non-null  object
#  15  행정동코드      528311 non-null  int64
#  16  행정동명       528311 non-null  object
#  17  법정동코드      528311 non-null  int64
#  18  법정동명       528311 non-null  object
# ...

# %%
columns_df = df.columns
columns_df_df
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df['시도명'] = df['시도명'].str.lstrip()
df
# Out:
#           상가업소번호        상호명        지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19917773       대구통닭  통통치킨상인2호점         Q       음식       Q05
# 1       19919475        빵마루        NaN         Q       음식       Q08
# 2       19925178       오구피자        NaN         Q       음식       Q07
# 3       19907335   명진가마솥오곡밥        NaN         Q       음식       Q01
# 4       19909700    이오쇠고기국밥        NaN         Q       음식       Q01
# ...          ...        ...        ...       ...      ...       ...
# 528306  16314214        A모텔        NaN         O       숙박       O02
# 528307  16292329       하얀기쁨        NaN         F    생활서비스       F02
# 528308  16292506        쭈네일        NaN         F    생활서비스       F01
# 528309  16394366     효소먹은돼지        NaN         Q       음식       Q01
# 528310  16335149  더칼라네일&속눈썹        NaN         F    생활서비스       F01
#
#          상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호     건물명  \
# ...

# %%
daegu =  df[df['시도명']== "대구광역시"]
daegu
# Out:
#           상가업소번호        상호명        지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19917773       대구통닭  통통치킨상인2호점         Q       음식       Q05
# 1       19919475        빵마루        NaN         Q       음식       Q08
# 4       19909700    이오쇠고기국밥        NaN         Q       음식       Q01
# 11      19921253         미화        NaN         Q       음식       Q03
# 12      19921284        충무회        NaN         Q       음식       Q03
# ...          ...        ...        ...       ...      ...       ...
# 528303  16369125  동녘바다머구리해물        NaN         Q       음식       Q03
# 528304  16368237   해녀조개돌문어탕        NaN         Q       음식       Q03
# 528305  16372423   민영이수제돈까스        NaN         Q       음식       Q06
# 528306  16314214        A모텔        NaN         O       숙박       O02
# 528310  16335149  더칼라네일&속눈썹        NaN         F    생활서비스       F01
#
#          상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호     건물명  \
# ...

# %%
daegu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129875 entries, 0 to 528310
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     129875 non-null  int64
#  1   상호명        129875 non-null  object
#  2   지점명        15247 non-null   object
#  3   상권업종대분류코드  129875 non-null  object
#  4   상권업종대분류명   129875 non-null  object
#  5   상권업종중분류코드  129875 non-null  object
#  6   상권업종중분류명   129875 non-null  object
#  7   상권업종소분류코드  129875 non-null  object
#  8   상권업종소분류명   129875 non-null  object
#  9   표준산업분류코드   122274 non-null  object
#  10  표준산업분류명    122274 non-null  object
#  11  시도코드       129875 non-null  int64
#  12  시도명        129875 non-null  object
#  13  시군구코드      129875 non-null  int64
#  14  시군구명       129875 non-null  object
#  15  행정동코드      129875 non-null  int64
#  16  행정동명       129875 non-null  object
#  17  법정동코드      129875 non-null  int64
#  18  법정동명       129875 non-null  object
# ...

# %%
daegu.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
col_filtered = daegu[['상가업소번호','상호명','상권업종중분류명','시군구명','행정동명','지번주소','도로명주소','경도','위도']]
col_filtered
# Out:
#           상가업소번호        상호명   상권업종중분류명 시군구명     행정동명                   지번주소  \
# 0       19917773       대구통닭     닭/오리요리  달서구     상인1동  대구광역시 달서구 상인동 1531-12
# 1       19919475        빵마루    제과제빵떡케익  수성구     지산1동    대구광역시 수성구 지산동 761-8
# 4       19909700    이오쇠고기국밥         한식   중구     대봉1동      대구광역시 중구 대봉동 12-9
# 11      19921253         미화     일식/수산물   중구      동인동  대구광역시 중구 동인동4가 248-20
# 12      19921284        충무회     일식/수산물  수성구      두산동   대구광역시 수성구 두산동 154-26
# ...          ...        ...        ...  ...      ...                    ...
# 528303  16369125  동녘바다머구리해물     일식/수산물  수성구      두산동   대구광역시 수성구 두산동 138-14
# 528304  16368237   해녀조개돌문어탕     일식/수산물  수성구  수성2.3가동  대구광역시 수성구 수성동2가 238-3
# 528305  16372423   민영이수제돈까스         양식  달서구      성당동    대구광역시 달서구 성당동 704-5
# 528306  16314214        A모텔  모텔/여관/여인숙   동구     신천4동     대구광역시 동구 신천동 325-7
# 528310  16335149  더칼라네일&속눈썹    이/미용/건강  달서구      본리동    대구광역시 달서구 본리동 145-5
#
#                        도로명주소          경도         위도
# ...

# %%
col_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129875 entries, 0 to 528310
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상가업소번호    129875 non-null  int64
#  1   상호명       129875 non-null  object
#  2   상권업종중분류명  129875 non-null  object
#  3   시군구명      129875 non-null  object
#  4   행정동명      129875 non-null  object
#  5   지번주소      129875 non-null  object
#  6   도로명주소     129875 non-null  object
#  7   경도        129875 non-null  float64
#  8   위도        129875 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.9+ MB

# %%
cafe_df = col_filtered[col_filtered['상권업종중분류명']=="커피점/카페"]
cafe_df
# Out:
#           상가업소번호       상호명 상권업종중분류명 시군구명   행정동명                    지번주소  \
# 116     20923824       브라운   커피점/카페  수성구   고산2동       대구광역시 수성구 노변동 353
# 627     22699925      카페신라   커피점/카페   중구   성내1동       대구광역시 중구 동문동 20-4
# 705     22852327        미도   커피점/카페   중구   성내2동      대구광역시 중구 종로2가 66-1
# 1006    25347698         썸   커피점/카페   북구    읍내동    대구광역시 북구 읍내동 1236-47
# 1018    25504085      까치찻집   커피점/카페  수성구   지산1동   대구광역시 수성구 지산동 1277-19
# ...          ...       ...      ...  ...    ...                     ...
# 527946  16360946    미메이트커피   커피점/카페  달서구   상인1동       대구광역시 달서구 상인동 926
# 528017  16364456      미쁜과일   커피점/카페   동구   신암1동      대구광역시 동구 신암동 738-3
# 528039  16318876       커맥스   커피점/카페  수성구  수성4가동  대구광역시 수성구 수성동4가 1090-8
# 528041  16318708  마커스커피컴퍼니   커피점/카페  수성구   고산2동     대구광역시 수성구 시지동 485-1
# 528264  16365855     몬스터커피   커피점/카페   북구   침산3동     대구광역시 북구 침산동 269-10
#
#                          도로명주소          경도         위도
# ...

# %%
cafe_df.head()
# Out:
#         상가업소번호   상호명 상권업종중분류명 시군구명  행정동명                   지번주소  \
# 116   20923824   브라운   커피점/카페  수성구  고산2동      대구광역시 수성구 노변동 353
# 627   22699925  카페신라   커피점/카페   중구  성내1동      대구광역시 중구 동문동 20-4
# 705   22852327    미도   커피점/카페   중구  성내2동     대구광역시 중구 종로2가 66-1
# 1006  25347698     썸   커피점/카페   북구   읍내동   대구광역시 북구 읍내동 1236-47
# 1018  25504085  까치찻집   커피점/카페  수성구  지산1동  대구광역시 수성구 지산동 1277-19
#
#                        도로명주소          경도         위도
# 116         대구광역시 수성구 노변로 55  128.699230  35.835111
# 627       대구광역시 중구 경상감영길 171  128.596926  35.872581
# 705      대구광역시 중구 중앙대로77길 19  128.592485  35.868132
# 1006  대구광역시 북구 칠곡중앙대로 614-29  128.554131  35.949804
# 1018       대구광역시 수성구 지범로 145  128.636445  35.823590

# %%
cafe_df1 = cafe_df.drop_duplicates(['상가업소번호','지번주소'],keep='first')
cafe_df1
# Out:
#           상가업소번호       상호명 상권업종중분류명 시군구명   행정동명                    지번주소  \
# 116     20923824       브라운   커피점/카페  수성구   고산2동       대구광역시 수성구 노변동 353
# 627     22699925      카페신라   커피점/카페   중구   성내1동       대구광역시 중구 동문동 20-4
# 705     22852327        미도   커피점/카페   중구   성내2동      대구광역시 중구 종로2가 66-1
# 1006    25347698         썸   커피점/카페   북구    읍내동    대구광역시 북구 읍내동 1236-47
# 1018    25504085      까치찻집   커피점/카페  수성구   지산1동   대구광역시 수성구 지산동 1277-19
# ...          ...       ...      ...  ...    ...                     ...
# 527946  16360946    미메이트커피   커피점/카페  달서구   상인1동       대구광역시 달서구 상인동 926
# 528017  16364456      미쁜과일   커피점/카페   동구   신암1동      대구광역시 동구 신암동 738-3
# 528039  16318876       커맥스   커피점/카페  수성구  수성4가동  대구광역시 수성구 수성동4가 1090-8
# 528041  16318708  마커스커피컴퍼니   커피점/카페  수성구   고산2동     대구광역시 수성구 시지동 485-1
# 528264  16365855     몬스터커피   커피점/카페   북구   침산3동     대구광역시 북구 침산동 269-10
#
#                          도로명주소          경도         위도
# ...

# %%
all_names = pd.Series(cafe_df1.상호명.unique())
all_names
# Out:
# 0            브라운
# 1           카페신라
# 2             미도
# 3              썸
# 4           까치찻집
#           ...
# 3338        꼬모맨션
# 3339      미메이트커피
# 3340        미쁜과일
# 3341         커맥스
# 3342    마커스커피컴퍼니
# Length: 3343, dtype: object

# %%
search_cafe_starbucks = all_names[all_names.str.contains('스타벅스')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-e29f79be16bb> in <module>
# ----> 1 search_cafe_starbucks = all_names[all_names.str.contains('스타벅스')]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     905             key = list(key)
#     906
# --> 907         if com.is_bool_indexer(key):
#     908             key = check_bool_indexer(self.index, key)
#     909
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
search_cafe_starbucks

# %%
cafe_unique_ediya = pd.Series(cafe_df.상호명)
cafe_ediya = cafe_unique_ediya[cafe_unique_ediya.str.contains('이디야')]
cafe_ediya
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-1e248d234915> in <module>
#       1 cafe_unique_ediya = pd.Series(cafe_df.상호명)
# ----> 2 cafe_ediya = cafe_unique_ediya[cafe_unique_ediya.str.contains('이디야')]
#       3 cafe_ediya
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     905             key = list(key)
#     906
# --> 907         if com.is_bool_indexer(key):
#     908             key = check_bool_indexer(self.index, key)
#     909
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ...
