# %%
order_id : 주문번호
quantity : 아이템의 주문수량
item_name : 아이템 이름
choice_description : 주문아이템 상세 선택 옵션
item_price : 주문아이템의 가격

1. 가장많이 주문한 아이템 top 10
2. 가장 비싼 아이템 총 몇개 팔렸을까?
3. Veggie Salad Bowl 이 몇 번 주문되었을까?

# %%
import pandas as pd
file_path = '/Users/w//data//chipotle.tsv'
chipo = pd.read_csv(file_path, sep ='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data = pd.DataFrame(chipo)

# %%
data1 = data[['quantity','item_name','item_price']]
data1
# Out:
#       quantity                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito    $11.75
# 4618         1                          Steak Burrito    $11.75
# 4619         1                     Chicken Salad Bowl    $11.25
# 4620         1                     Chicken Salad Bowl     $8.75
# 4621         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 3 columns]

# %%
data1['int_item_price'] = data1.item_price.replace("$"," ")
data1
# Out:
#       quantity                              item_name item_price  \
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito    $11.75
# 4618         1                          Steak Burrito    $11.75
# 4619         1                     Chicken Salad Bowl    $11.25
# 4620         1                     Chicken Salad Bowl     $8.75
# 4621         1                     Chicken Salad Bowl     $8.75
#
#      int_item_price
# 0            $2.39
# 1            $3.39
# 2            $3.39
# 3            $2.39
# 4           $16.98
# ...             ...
# 4617        $11.75
# 4618        $11.75
# ...

# %%
data['item_name'].value_counts(['quantity'])[:10]
# Out:
# Chicken Bowl           0.157075
# Chicken Burrito        0.119645
# Chips and Guacamole    0.103635
# Steak Burrito          0.079619
# Canned Soft Drink      0.065123
# Steak Bowl             0.045651
# Chips                  0.045651
# Bottled Water          0.035050
# Chicken Soft Tacos     0.024881
# Chicken Salad Bowl     0.023799
# Name: item_name, dtype: float64

# %%
data.sort_values(by='item_price', ascending=False)
# Out:
#       order_id  quantity            item_name  \
# 2624      1042         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# ...        ...       ...                  ...
# 3145      1254         1          Canned Soda
# 414        180         1          Canned Soda
# 3162      1262         1          Canned Soda
# 821        338         1          Canned Soda
# 1457       591         1          Canned Soda
#
#                                      choice_description item_price
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
# 4419  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4036  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39
# 1825  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 3115  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.39
# ...

# %%
data['item_name'].value_counts(['quantity',['Veggie Salad Bowl']])[]
# Out:
#   File "<ipython-input-82-81300a30d5d3>", line 1
#     data['item_name'].value_counts(['quantity',['Veggie Salad Bowl']])[]
#                                                                        ^
# SyntaxError: invalid syntax
