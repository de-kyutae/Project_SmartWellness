# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/6270000/6270000_대구광역시_07_24_04_P_일반음식점.xlsx')

# %%
df= df.copy()
df.head()
# Out:
#    번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0   1  일반음식점  07_24_04_P   3410000  3410000-101-2002-00042  20020321      NaN
# 1   2  일반음식점  07_24_04_P   3410000  3410000-101-2002-00043  20020322      NaN
# 2   3  일반음식점  07_24_04_P   3410000  3410000-101-2002-00046  20020322      NaN
# 3   4  일반음식점  07_24_04_P   3410000  3410000-101-2002-00067  20020325      NaN
# 4   5  일반음식점  07_24_04_P   3410000  3410000-101-2002-00041  20020325      NaN
#
#    영업상태구분코드 영업상태명  상세영업상태코드  ... 공장판매직종업원수  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 1         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 2         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 3         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 4         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
#
#   다중이용업소여부   시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# 0        N  144.58       NaN      NaN  NaN
# 1        N   59.55       NaN      NaN  NaN
# 2        N   42.78       NaN      NaN  NaN
# 3        N   77.01       NaN      NaN  NaN
# 4        N  140.58       NaN      NaN  NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ####

# %%
titles = df.columns
titles
# Out:
# Index(['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수',
#        '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액',
#        '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
drop_list= ['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태구분코드', '영업상태명', '상세영업상태코드', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '도로명전체주소', '도로명우편번호', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수', '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지']
df = df.drop(drop_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-930487b87dfa> in <module>
#       1 drop_list= ['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태구분코드', '영업상태명', '상세영업상태코드', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '도로명전체주소', '도로명우편번호', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수', '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지']
# ----> 2 df = df.drop(drop_list)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['번호' '개방서비스명' '개방서비스ID' '개방자치단체코드' '관리번호' '인허가일자' '인허가취소일자' '영업상태구분코드'\n '영업상태명' '상세영업상태코드' '폐업일자' '휴업시작일자' '휴업종료일자' '재개업일자' '소재지전화' '소재지면적'\n '소재지우편번호' '도로명전체주소' '도로명우편번호' '최종수정시점' '데이터갱신구분' '데이터갱신일자' '좌표정보(X)'\n '좌표정보(Y)' '위생업태명' '남성종사자수' '여성종사자수' '영업장주변구분명' '등급구분명' '급수시설구분명' '총종업원수'\n '본사종업원수' '공장사무직종업원수' '공장판매직종업원수' '공장생산직종업원수' '건물소유구분명' '보증액' '월세액'\n '다중이용업소여부' '시설총규모' '전통업소지정번호' '전통업소주된음식' '홈페이지'] not found in axis"

# %%
res = df[['상세영업상태명','소재지전체주소','사업장명','업태구분명']]
df = res
df
# Out:
#       상세영업상태명                           소재지전체주소         사업장명  업태구분명
# 0          폐업            대구광역시 중구 계산동2가 0171번지           옛날집     한식
# 1          폐업  대구광역시 중구 동성로3가 0016-0010번지 외7필지        명계안동찜닭     한식
# 2          폐업       대구광역시 중구 삼덕동1가 0022-0012번지        달구벌찜한식     한식
# 3          폐업       대구광역시 중구 동인동1가 0089-0002번지          맥향식당     한식
# 4          폐업         대구광역시 중구 문화동 0007-0007번지           차하늘     한식
# ...       ...                               ...          ...    ...
# 79202      영업           대구광역시 달성군 다사읍 서재리 91번지       칭구짬뽕서재점    중국식
# 79203      영업        대구광역시 달성군 다사읍 죽곡리 152-1번지        만나코다리찜     한식
# 79204      영업        대구광역시 달성군 다사읍 죽곡리 857-6번지   처갓집양념치킨 죽곡점  호프/통닭
# 79205      영업         대구광역시 달성군 가창면 옥분리 69-2번지          묵항아리     기타
# 79206      영업          대구광역시 달성군 하빈면 현내리 932번지          부영식당     한식
#
# [79207 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79207 entries, 0 to 79206
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   상세영업상태명  79207 non-null  object
#  1   소재지전체주소  79181 non-null  object
#  2   사업장명     79207 non-null  object
#  3   업태구분명    79204 non-null  object
# dtypes: object(4)
# memory usage: 2.4+ MB

# %% [markdown]
# ### 결측치 삭제

# %%
df = df.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79178 entries, 0 to 79206
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   상세영업상태명  79178 non-null  object
#  1   소재지전체주소  79178 non-null  object
#  2   사업장명     79178 non-null  object
#  3   업태구분명    79178 non-null  object
# dtypes: object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ### 앞공백제거

# %%
df['소재지전체주소'] = df['소재지전체주소'].str.lstrip()
df
# Out:
# <ipython-input-80-cdbdb63cf057>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['소재지전체주소'] = df['소재지전체주소'].str.lstrip()
#       상세영업상태명                           소재지전체주소         사업장명  업태구분명
# 0          폐업            대구광역시 중구 계산동2가 0171번지           옛날집     한식
# 1          폐업  대구광역시 중구 동성로3가 0016-0010번지 외7필지        명계안동찜닭     한식
# 2          폐업       대구광역시 중구 삼덕동1가 0022-0012번지        달구벌찜한식     한식
# 3          폐업       대구광역시 중구 동인동1가 0089-0002번지          맥향식당     한식
# 4          폐업         대구광역시 중구 문화동 0007-0007번지           차하늘     한식
# ...       ...                               ...          ...    ...
# 79202      영업           대구광역시 달성군 다사읍 서재리 91번지       칭구짬뽕서재점    중국식
# 79203      영업        대구광역시 달성군 다사읍 죽곡리 152-1번지        만나코다리찜     한식
# 79204      영업        대구광역시 달성군 다사읍 죽곡리 857-6번지   처갓집양념치킨 죽곡점  호프/통닭
# 79205      영업         대구광역시 달성군 가창면 옥분리 69-2번지          묵항아리     기타
# 79206      영업          대구광역시 달성군 하빈면 현내리 932번지          부영식당     한식
#
# [79178 rows x 4 columns]

# %%
df = df[df['상세영업상태명'] == '영업']
df
# Out:
#       상세영업상태명                      소재지전체주소             사업장명       업태구분명
# 4579       영업  대구광역시 중구 삼덕동3가 0277-0006번지             에이글라스         경양식
# 4580       영업  대구광역시 중구 삼덕동3가 0177-0001번지                 담          일식
# 4581       영업  대구광역시 중구 동인동3가 0271-0001번지              울릉식당          한식
# 4582       영업         대구광역시 중구 동산동 0802번지              대영식당          한식
# 4583       영업         대구광역시 중구 공평동 0093번지   뉴스쿨(NEW SCHOOL)  정종/대포집/소주방
# ...       ...                          ...              ...         ...
# 79202      영업      대구광역시 달성군 다사읍 서재리 91번지           칭구짬뽕서재점         중국식
# 79203      영업   대구광역시 달성군 다사읍 죽곡리 152-1번지            만나코다리찜          한식
# 79204      영업   대구광역시 달성군 다사읍 죽곡리 857-6번지       처갓집양념치킨 죽곡점       호프/통닭
# 79205      영업    대구광역시 달성군 가창면 옥분리 69-2번지              묵항아리          기타
# 79206      영업     대구광역시 달성군 하빈면 현내리 932번지              부영식당          한식
#
# [30509 rows x 4 columns]

# %%
df[['시도','구','동','나머지']] = df['소재지전체주소'].str.split(' ', n=3, expand=True)
df.head()
# Out:
# C:\Users\w\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      상세영업상태명                      소재지전체주소             사업장명       업태구분명     시도  \
# 4579      영업  대구광역시 중구 삼덕동3가 0277-0006번지             에이글라스         경양식  대구광역시
# 4580      영업  대구광역시 중구 삼덕동3가 0177-0001번지                 담          일식  대구광역시
# 4581      영업  대구광역시 중구 동인동3가 0271-0001번지              울릉식당          한식  대구광역시
# 4582      영업         대구광역시 중구 동산동 0802번지              대영식당          한식  대구광역시
# 4583      영업         대구광역시 중구 공평동 0093번지   뉴스쿨(NEW SCHOOL)  정종/대포집/소주방  대구광역시
#
#        구      동           나머지
# 4579  중구  삼덕동3가  0277-0006번지
# 4580  중구  삼덕동3가  0177-0001번지
# 4581  중구  동인동3가  0271-0001번지
# 4582  중구    동산동       0802번지
# 4583  중구    공평동       0093번지

# %%
drop_list2 = ['소재지전체주소','사업장명','시도','나머지']
df = df.drop(drop_list2, axis=1)
df.head()
# Out:
#      상세영업상태명       업태구분명   구      동
# 4579      영업         경양식  중구  삼덕동3가
# 4580      영업          일식  중구  삼덕동3가
# 4581      영업          한식  중구  동인동3가
# 4582      영업          한식  중구    동산동
# 4583      영업  정종/대포집/소주방  중구    공평동

# %% [markdown]
# ### 통닭이 들어간 것을 다 찾아라.

# %%
all_names = pd.Series(df.업태구분명.unique())
chicken_like = all_names[all_names.str.contains('통닭')]
chicken_like
# Out:
# 5      호프/통닭
# 12    통닭(치킨)
# dtype: object

# %%
df = df[df['업태구분명'].isin(chicken_like)]
df.head()
# Out:
#      상세영업상태명  업태구분명   구      동
# 4589      영업  호프/통닭  중구    공평동
# 4604      영업  호프/통닭  중구    남산동
# 4627      영업  호프/통닭  중구    남산동
# 4684      영업  호프/통닭  중구  삼덕동1가
# 4699      영업  호프/통닭  중구    남성로

# %%
df = df[df['업태구분명'].isin(["호프/통닭","통닭(치킨)"])]
df.head()
# Out:
#      상세영업상태명  업태구분명   구      동
# 4589      영업  호프/통닭  중구    공평동
# 4604      영업  호프/통닭  중구    남산동
# 4627      영업  호프/통닭  중구    남산동
# 4684      영업  호프/통닭  중구  삼덕동1가
# 4699      영업  호프/통닭  중구    남성로

# %%
df.dtypes
# Out:
# 상세영업상태명    object
# 업태구분명      object
# 구          object
# 동          object
# dtype: object

# %%
df['count'] = 1
df
# Out:
#       상세영업상태명   업태구분명    구      동  count
# 4589       영업   호프/통닭   중구    공평동      1
# 4604       영업   호프/통닭   중구    남산동      1
# 4627       영업   호프/통닭   중구    남산동      1
# 4684       영업   호프/통닭   중구  삼덕동1가      1
# 4699       영업   호프/통닭   중구    남성로      1
# ...       ...     ...  ...    ...    ...
# 79184      영업   호프/통닭  달성군    화원읍      1
# 79186      영업  통닭(치킨)  달성군    논공읍      1
# 79189      영업  통닭(치킨)  달성군    다사읍      1
# 79200      영업  통닭(치킨)  달성군    현풍읍      1
# 79204      영업   호프/통닭  달성군    다사읍      1
#
# [3367 rows x 5 columns]

# %%
chicken = df.groupby('동').sum()
chicken = chicken.sort_values(by='count', ascending=False)
chicken.head()
# Out:
#      count
# 동
# 대명동    149
# 다사읍    118
# 상인동    111
# 태전동     92
# 평리동     91

# %%
ids, cols = np.where(chicken == chicken.values.max())
chicken.iloc[ids]
# Out:
#      count
# 동
# 대명동    149

# %%
top10 = chicken.sort_values(by='count' ,ascending=False)[:10]
top10
# Out:
#      count
# 동
# 대명동    149
# 다사읍    118
# 상인동    111
# 태전동     92
# 평리동     91
# 신암동     88
# 비산동     82
# 산격동     81
# 송현동     76
# 두류동     72

# %%
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
font_path = 'C:/Windows/Fonts/NGULIM.TTF'
fontprop = fm.FontProperties(fname=font_path, size=15)
font_family = fm.FontProperties(fname=font_path).get_name()
plt.rcParams["font.family"] = font_family

# %%
top10_values = list(np.ravel(top10.values))
x = np.arange(len(top10_values))  # the label locations
width = 0.6  # the width of the bars

# %%
fig, ax = plt.subplots(figsize=(10, 6)) #fig, ax = plt.subplots(TOTAL_X,TOTAL_Y,figsize=(8, 5))
plt.grid(b=True, which='both', axis='both')
rects1 = ax.bar(top10.index, top10_values, width, align='center', alpha=0.5, label='치킨집 수')
rects1[top10_values.index(max(top10_values))].set_color('g')

ax.set_title('동네별 치킨집의 수 Top10')
ax.set_xticks(x)
ax.set_xticklabels(top10.index)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
fig.tight_layout()

plt.show()

# %%
chicken_gu = df.groupby('구').sum()
chicken_gu
# Out:
#      count
# 구
# 남구     207
# 달서구    841
# 달성군    394
# 동구     422
# 북구     618
# 서구     249
# 수성구    453
# 중구     183

# %%
print(chicken_gu.values)
print(chicken_gu.index)
# Out:
# [[207]
#  [841]
#  [394]
#  [422]
#  [618]
#  [249]
#  [453]
#  [183]]
# Index(['남구', '달서구', '달성군', '동구', '북구', '서구', '수성구', '중구'], dtype='object', name='구')

# %%
num_chicken = list(np.ravel(chicken_gu.values))
num_chicken
# Out:
# [207, 841, 394, 422, 618, 249, 453, 183]

# %%
g, ax = plt.subplots(figsize=(8, 5))
plt.grid(b=True, which='both', axis='both')
bar_list = plt.bar(chicken_gu.index, num_chicken, align='center', alpha=0.5)
bar_list[num_chicken.index(max(num_chicken))].set_color('g')
# plt.plot([0., 7], [chicken3.loc['동구'], chicken3.loc['동구']], "m--")
plt.title('구별 치킨집의 수')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6)) #fig, ax = plt.subplots(TOTAL_X,TOTAL_Y,figsize=(8, 5))
plt.grid(b=True, which='both', axis='both')
rects2 = ax.bar(num_chicken.index, num_chicken_values, width, align='center', alpha=0.5, label='치킨집 수')
rects2[num_chicken_values.index(max(num_chicken_values))].set_color('g')

ax.set_title('구별 치킨집의 수 Top10')
ax.set_xticks(x)
ax.set_xticklabels(num_chicken.index)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects2)
fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-e1a9da3b65f0> in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 6)) #fig, ax = plt.subplots(TOTAL_X,TOTAL_Y,figsize=(8, 5))
#       2 plt.grid(b=True, which='both', axis='both')
# ----> 3 rects2 = ax.bar(num_chicken.index, num_chicken_values, width, align='center', alpha=0.5, label='치킨집 수')
#       4 rects2[num_chicken_values.index(max(num_chicken_values))].set_color('g')
#       5
#
# NameError: name 'num_chicken_values' is not defined

# %%
soo7_upsoo7_up
