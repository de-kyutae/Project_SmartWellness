# %%
1. 10살 단위로 인구 정리한다.(인구를 0-10, 11-20,.. 70이상)
2. 70대 이상은 하나로 합친다.
3. 3개의 기간동안 인구가 증가하는 곳을 찾는다.
4. 남성이 여성보다 많이 거주하는 곳 가운데 인구가 3만 이상인 곳을 찾는다. (없으면 없다고...)

# %%
import pandas as pd
import numpy as np

# %%
df1806 = pd.read_csv('data/2018.06.30.기준 대구광역시 주민등록인구 현황_UTF8.csv' ,encoding='utf-8')
df1812 = pd.read_csv('data/2018.12.31.기준 대구광역시 주민등록인구 현황_UTF8.csv' ,encoding='utf-8')
df1906 = pd.read_csv('data/2019.06.30.기준 대구광역시 주민등록인구 현황_UTF8.csv' ,encoding='utf-8')

df1806
df1812
# Out:
#           구분     총계   총계 남  총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  ...  \
# 0         0세  13993   7075  6918   521   272   249  2173  1100  1073  ...
# 1         1세  16306   8442  7864   548   278   270  2569  1365  1204  ...
# 2         2세  18774   9576  9198   656   325   331  2875  1433  1442  ...
# 3         3세  20010  10252  9758   639   324   315  3055  1592  1463  ...
# 4         4세  20020  10219  9801   594   310   284  3055  1541  1514  ...
# ..       ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...
# 96       96세    369     74   295    21     1    20    62    10    52  ...
# 97       97세    273     46   227    17     3    14    45    10    35  ...
# 98       98세    178     37   141    18     6    12    31     9    22  ...
# 99       99세    130     25   105     8     3     5    27     7    20  ...
# 100  100세 이상    628    145   483    85    15    70   110    25    85  ...
#
#      북구 여  수성구 계  수성구 남  수성구 여  달서구 계  달서구 남  달서구 여  달성군 계  달성군 남  달성군 여
# ...

# %%
import re
row=0
for i in df1806['구분']:
    df1806['구분'][row] = re.sub('[^0-9]',repl='',string=i)
    row +=1
df1806
# Out:
#       구분     총계   총계 남  총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  ...  북구 여  \
# 0      0  14568   7488  7080   511   275   236  2263  1161  1102  ...  1356
# 1      1  17475   8947  8528   609   309   300  2755  1410  1345  ...  1670
# 2      2  19562   9985  9577   612   308   304  3000  1467  1533  ...  1847
# 3      3  20123  10249  9874   648   315   333  3146  1656  1490  ...  1856
# 4      4  19794  10069  9725   556   287   269  2971  1519  1452  ...  1846
# ..   ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 96    96    365     75   290    23     3    20    66    10    56  ...    37
# 97    97    235     45   190    18     3    15    35    13    22  ...    36
# 98    98    190     32   158    16     7     9    33     6    27  ...    30
# 99    99    112     26    86     6     1     5    25     7    18  ...    13
# 100  100    614    136   478    88    15    73   106    23    83  ...    52
#
# ...

# %%
row=0
for i in df1806['구분']:
    df1806['구분'][row] = int(df1806['구분'][row])
    row += 1
df1806
# Out:
#       구분     총계   총계 남  총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  ...  북구 여  \
# 0      0  14568   7488  7080   511   275   236  2263  1161  1102  ...  1356
# 1      1  17475   8947  8528   609   309   300  2755  1410  1345  ...  1670
# 2      2  19562   9985  9577   612   308   304  3000  1467  1533  ...  1847
# 3      3  20123  10249  9874   648   315   333  3146  1656  1490  ...  1856
# 4      4  19794  10069  9725   556   287   269  2971  1519  1452  ...  1846
# ..   ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 96    96    365     75   290    23     3    20    66    10    56  ...    37
# 97    97    235     45   190    18     3    15    35    13    22  ...    36
# 98    98    190     32   158    16     7     9    33     6    27  ...    30
# 99    99    112     26    86     6     1     5    25     7    18  ...    13
# 100  100    614    136   478    88    15    73   106    23    83  ...    52
#
# ...

# %%
구분 = pd.cut(df1806['구분'],[0,10,20,30,40,50,60,70])
df1806['구분']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 96      96
# 97      97
# 98      98
# 99      99
# 100    100
# Name: 구분, Length: 101, dtype: object

# %%
#df1806.groupby(df1806['구분']).sum()
# Out:
#             총계   총계 남   총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  서구 계  ...  \
# 구분                                                                      ...
# 0세       14568   7488   7080   511   275   236  2263  1161  1102   719  ...
# 100세 이상    614    136    478    88    15    73   106    23    83    89  ...
# 10세      22770  11717  11053   505   256   249  2958  1487  1471  1066  ...
# 11세      21602  11124  10478   446   245   201  2695  1407  1288  1045  ...
# 12세      21015  11007  10008   457   241   216  2447  1295  1152  1045  ...
# ...        ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...
# 96세        365     75    290    23     3    20    66    10    56    30  ...
# 97세        235     45    190    18     3    15    35    13    22    18  ...
# 98세        190     32    158    16     7     9    33     6    27    15  ...
# 99세        112     26     86     6     1     5    25     7    18    10  ...
# ...

# %%
df.head()
# Out:
#   구분     총계   총계 남  총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  ...  북구 여  \
# 0  0  14568   7488  7080   511   275   236  2263  1161  1102  ...  1356
# 1  1  17475   8947  8528   609   309   300  2755  1410  1345  ...  1670
# 2  2  19562   9985  9577   612   308   304  3000  1467  1533  ...  1847
# 3  3  20123  10249  9874   648   315   333  3146  1656  1490  ...  1856
# 4  4  19794  10069  9725   556   287   269  2971  1519  1452  ...  1846
#
#    수성구 계  수성구 남  수성구 여  달서구 계  달서구 남  달서구 여  달성군 계  달성군 남  달성군 여
# 0   1784    911    873   3215   1719   1496   2724   1374   1350
# 1   2264   1170   1094   3818   2017   1801   3063   1543   1520
# 2   2684   1410   1274   4423   2317   2106   3327   1668   1659
# 3   2876   1423   1453   4661   2366   2295   3253   1638   1615
# 4   3089   1596   1493   4529   2294   2235   3036   1512   1524
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      101 non-null    object
#  1   총계      101 non-null    int64
#  2   총계 남    101 non-null    int64
#  3   총계 여    101 non-null    int64
#  4   중구 계    101 non-null    int64
#  5   중구 남    101 non-null    int64
#  6   중구 여    101 non-null    int64
#  7   동구 계    101 non-null    int64
#  8   동구 남    101 non-null    int64
#  9   동구 여    101 non-null    int64
#  10  서구 계    101 non-null    int64
#  11  서구 남    101 non-null    int64
#  12  서구 여    101 non-null    int64
#  13  남구 계    101 non-null    int64
#  14  남구 남    101 non-null    int64
#  15  남구 여    101 non-null    int64
#  16  북구 계    101 non-null    int64
#  17  북구 남    101 non-null    int64
#  18  북구 여    101 non-null    int64
#  19  수성구 계   101 non-null    int64
#  20  수성구 남   101 non-null    int64
#  21  수성구 여   101 non-null    int64
# ...

# %%
df.describe()
# Out:
#                  총계          총계 남          총계 여         중구 계        중구 남  \
# count    101.000000    101.000000    101.000000   101.000000  101.000000
# mean   24451.653465  12120.059406  12331.594059   777.524752  377.168317
# std    13881.135558   7210.290994   6753.665704   407.407869  211.933295
# min      112.000000     26.000000     86.000000     6.000000    1.000000
# 25%    14568.000000   6660.000000   8528.000000   504.000000  241.000000
# 50%    25939.000000  12788.000000  12361.000000   853.000000  376.000000
# 75%    35348.000000  18378.000000  17298.000000  1153.000000  566.000000
# max    47485.000000  23154.000000  24384.000000  1388.000000  683.000000
#
#              중구 여         동구 계         동구 남         동구 여         서구 계  ...  \
# count  101.000000   101.000000   101.000000   101.000000   101.000000  ...
# mean   400.356436  3484.079208  1726.158416  1757.920792  1868.366337  ...
# std    199.657185  1879.798344   976.818588   921.110793  1168.004278  ...
# ...

# %%
df.columns
# Out:
# Index(['구분', '총계', '총계 남', '총계 여', '중구 계', '중구 남', '중구 여', '동구 계', '동구 남',
#        '동구 여', '서구 계', '서구 남', '서구 여', '남구 계', '남구 남', '남구 여', '북구 계', '북구 남',
#        '북구 여', '수성구 계', '수성구 남', '수성구 여', '달서구 계', '달서구 남', '달서구 여', '달성군 계',
#        '달성군 남', '달성군 여'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=101, step=1)

# %%
df.duplicated().value_counts()
# Out:
# False    101
# dtype: int64

# %%
import re
row=0
for i in df['구분']:
    df['구분'][row] = re.sub('[^0-9]',repl='',string=i)
    row +=1
df
# Out:
#       구분     총계   총계 남  총계 여  중구 계  중구 남  중구 여  동구 계  동구 남  동구 여  ...  북구 여  \
# 0      0  14568   7488  7080   511   275   236  2263  1161  1102  ...  1356
# 1      1  17475   8947  8528   609   309   300  2755  1410  1345  ...  1670
# 2      2  19562   9985  9577   612   308   304  3000  1467  1533  ...  1847
# 3      3  20123  10249  9874   648   315   333  3146  1656  1490  ...  1856
# 4      4  19794  10069  9725   556   287   269  2971  1519  1452  ...  1846
# ..   ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 96    96    365     75   290    23     3    20    66    10    56  ...    37
# 97    97    235     45   190    18     3    15    35    13    22  ...    36
# 98    98    190     32   158    16     7     9    33     6    27  ...    30
# 99    99    112     26    86     6     1     5    25     7    18  ...    13
# 100  100    614    136   478    88    15    73   106    23    83  ...    52
#
# ...

# %%
df['구분'][12]
# Out:
# '12'

# %%
df[0][0:9]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ca4745bc399e> in <module>
# ----> 1 df[0][0:9]
#
# ...

# %%
df['구분'] = map(int,df['구분'])

# %%
bins = [0,10,20,30,40,50,60,101]
age = df['구분']
pd.cut(age,bins, right=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-7a7dcfe23604> in <module>
#       1 bins = [0,10,20,30,40,50,60,101]
#       2 age = df['구분']
# ----> 3 pd.cut(age,bins, right=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     255             raise ValueError("bins must increase monotonically.")
#     256
# --> 257     fac, bins = _bins_to_cuts(
#     258         x,
#     259         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ...
